# %%
pip install geoviews
# Out:
# Requirement already satisfied: geoviews in c:\users\danie\anaconda3\envs\dev\lib\site-packages (1.13.0)
# Requirement already satisfied: bokeh<3.6.0,>=3.5.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (3.5.2)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (0.24.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.20.0)
# Requirement already satisfied: numpy in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.26.4)
# Requirement already satisfied: packaging in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (24.1)
# Requirement already satisfied: panel>=1.0.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.5.2)
# Requirement already satisfied: param in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (2.1.1)
# Requirement already satisfied: pyproj in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: shapely in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (2.0.6)
# Requirement already satisfied: xyzservices in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (6.4.1)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.9.2)
# Requirement already satisfied: pyshp>=2.3 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: colorcet in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.2)
# Requirement already satisfied: bleach in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: markdown in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.11.0)
# Requirement already satisfied: certifi in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pyproj->geoviews) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh<3.6.0,>=3.5.0->geoviews) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh<3.6.0,>=3.5.0->geoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh<3.6.0,>=3.5.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.2.3)
# Requirement already satisfied: colorama in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from tqdm->panel>=1.0.0->geoviews) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install hvplot
# Out:
# Requirement already satisfied: hvplot in c:\users\danie\anaconda3\envs\dev\lib\site-packages (0.11.0)
# Requirement already satisfied: bokeh>=3.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (3.5.2)
# Requirement already satisfied: colorcet>=2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.19.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (1.20.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (1.26.4)
# Requirement already satisfied: packaging in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (24.1)
# Requirement already satisfied: pandas>=1.3 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (2.2.2)
# Requirement already satisfied: panel>=1.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (1.5.2)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from hvplot) (2.1.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh>=3.1->hvplot) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh>=3.1->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh>=3.1->hvplot) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh>=3.1->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh>=3.1->hvplot) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh>=3.1->hvplot) (2022.9.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.19.0->hvplot) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.3->hvplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.3->hvplot) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.3->hvplot) (2023.3)
# Requirement already satisfied: bleach in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (2.0.0)
# Requirement already satisfied: markdown in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from panel>=1.0->hvplot) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->hvplot) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->hvplot) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from linkify-it-py->panel>=1.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from markdown-it-py->panel>=1.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0->hvplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0->hvplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0->hvplot) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0->hvplot) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from tqdm->panel>=1.0->hvplot) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\danie\anaconda3\envs\dev\lib\site-packages (3.5.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (24.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\danie\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
#import hvplot.pandas
#import pandas as pd
#import hvplot.pandas
#import holoviews as hv
#hv.extension('bokeh')
#from bokeh.plotting import show
#import geoviews


import hvplot.pandas
import pandas as pd


# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

import requests
import json

import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='dc53a53b-a361-48d4-aa68-0929147546e0'>
#   <div id="c0d76104-8b1f-4ef2-aa86-756fd1da7a7e" data-root-id="dc53a53b-a361-48d4-aa68-0929147546e0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5f833097-cebe-4000-bcab-29b39d967267":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"dc53a53b-a361-48d4-aa68-0929147546e0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"dfe5fe21-6d6d-4865-b0d0-aae88214e88e","attributes":{"plot_id":"dc53a53b-a361-48d4-aa68-0929147546e0","comm_id":"7485a029f555431e9851b0a8316b9ede","client_comm_id":"6e0c123e5f77444082bcd6a6ced8eb63"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"5f833097-cebe-4000-bcab-29b39d967267","roots":{"dc53a53b-a361-48d4-aa68-0929147546e0":"c0d76104-8b1f-4ef2-aa86-756fd1da7a7e"},"root_ids":["dc53a53b-a361-48d4-aa68-0929147546e0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 0        0          kaa-khem  51.6833   94.7333    271.93        62
# 1        1            gaogou  34.0175  119.1886    288.74        73
# 2        2            namibe -15.1961   12.1522    294.55        72
# 3        3          linhares -19.3911  -40.0722    294.34        84
# 4        4  chahal guatemala  15.7500  -89.5667    295.51        98
#
#    Cloudiness  Wind Speed Country        Date
# 0          91        1.50      RU  1731370768
# 1           5        1.05      CN  1731370770
# 2           2        2.24      AO  1731370771
# 3          32        1.34      BR  1731370773
# 4          50        0.33      GT  1731370774

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

#NOTE: IF YOU CAN'T SE THE MAP TILE, PLEASE ALTERNATE BETWEEN TRUE OR FALSE VALUES FOR "GEO" PARAMETER

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    size = "Humidity",
    geo = False,
    tiles = "OSM",
    color = "City"
)

# Display the map


map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [x,y]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrow_df=city_data_df.loc[(city_data_df["Max Temp"]>=291)&(city_data_df["Wind Speed"]<4.5)&(city_data_df["Cloudiness"]==0)&(city_data_df["Max Temp"]<=301)]
#Temperature is expressed in Kelvins, so ranges were closely converted to 27 and 21 degrees celcius

# Drop any rows with null values
# There were no null 

# Display sample data
narrow_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 78        78           iowa park  33.9515  -98.6687    293.07        55
# 82        82         dhromolaxia  34.8755   33.5868    291.33        82
# 152      152      citrus springs  28.9975  -82.4707    298.10        77
# 193      193          fort bragg  35.1390  -79.0060    292.06        91
# 204      204              tiznit  29.5833   -9.5000    291.98        56
# 247      247                dori  14.0354   -0.0345    296.95        17
# 346      346  madinat ash shamal  26.1293   51.2009    299.23        70
# 350      350             omaruru -21.4333   15.9333    292.25        29
# 376      376              laurel  39.0993  -76.8483    291.49        64
# 389      389           kerrville  30.0474  -99.1403    298.07        60
# 404      404             salalah  17.0151   54.0924    296.20        60
# 420      420            mankapur  27.0333   82.2333    293.79        65
# 429      429               dunda  -8.1167   34.2500    292.93        68
# 443      443            cam ranh  11.9214  109.1591    298.13        94
# 446      446          jaguariuna -22.7056  -46.9858    297.86        54
# 470      470                tura  25.5198   90.2201    291.70        88
# 471      471        port augusta -32.5000  137.7667    298.20        52
# 502      502          shreveport  32.5251  -93.7502    294.27        56
# 551      551        saint-pierre -21.3393   55.4781    295.97        78
#
#      Cloudiness  Wind Speed Country        Date
# 78            0        1.54      US  1731370885
# 82            0        3.09      CY  1731370890
# 152           0        0.00      US  1731370995
# 193           0        2.06      US  1731371059
# 204           0        0.77      MA  1731371075
# 247           0        3.79      BF  1731371141
# 346           0        2.86      QA  1731371288
# 350           0        1.21     NaN  1731371294
# 376           0        2.57      US  1731371332
# 389           0        0.00      US  1731371108
# 404           0        1.03      OM  1731371378
# 420           0        1.00      IN  1731371404
# 429           0        0.98      TZ  1731371417
# 443           0        1.03      VN  1731371439
# 446           0        1.13      BR  1731371443
# 470           0        1.54      IN  1731371477
# 471           0        1.69      AU  1731371478
# 502           0        2.57      US  1731371346
# 551           0        2.06      RE  1731371595

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=narrow_df[["City","Country","Lat","Lng","Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 78            iowa park      US  33.9515  -98.6687        55
# 82          dhromolaxia      CY  34.8755   33.5868        82
# 152      citrus springs      US  28.9975  -82.4707        77
# 193          fort bragg      US  35.1390  -79.0060        91
# 204              tiznit      MA  29.5833   -9.5000        56
# 247                dori      BF  14.0354   -0.0345        17
# 346  madinat ash shamal      QA  26.1293   51.2009        70
# 350             omaruru     NaN -21.4333   15.9333        29
# 376              laurel      US  39.0993  -76.8483        64
# 389           kerrville      US  30.0474  -99.1403        60
# 404             salalah      OM  17.0151   54.0924        60
# 420            mankapur      IN  27.0333   82.2333        65
# 429               dunda      TZ  -8.1167   34.2500        68
# 443            cam ranh      VN  11.9214  109.1591        94
# 446          jaguariuna      BR -22.7056  -46.9858        54
# 470                tura      IN  25.5198   90.2201        88
# 471        port augusta      AU -32.5000  137.7667        52
# 502          shreveport      US  32.5251  -93.7502        56
# 551        saint-pierre      RE -21.3393   55.4781        78

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel

category="accommodation.hotel"

radius = 10000
params = {
   "apiKey":geoapify_key,
    "categories":category
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    latitude=hotel_df.loc[index, "Lat"]
    longitude=hotel_df.loc[index, "Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = requests.get(base_url, params=params).json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# iowa park - nearest hotel: No hotel found
# dhromolaxia - nearest hotel: Helen of Troy gardens
# citrus springs - nearest hotel: Comfort Suites
# fort bragg - nearest hotel: Airborne Inn Lodging
# tiznit - nearest hotel: No hotel found
# dori - nearest hotel: Kuin Deni Dori
# madinat ash shamal - nearest hotel: No hotel found
# omaruru - nearest hotel: Central Hotel
# laurel - nearest hotel: Quality Inn & Suites
# kerrville - nearest hotel: Inn Of The Hills
# salalah - nearest hotel: Muscat International Hotel
# mankapur - nearest hotel: No hotel found
# dunda - nearest hotel: No hotel found
# cam ranh - nearest hotel: Khách sạn Thái Bình
# jaguariuna - nearest hotel: Hotel Jaguary
# tura - nearest hotel: Hotel Polo Orchid
# port augusta - nearest hotel: Hotel Commonwealth
# shreveport - nearest hotel: Sam's Town Hotel and Casino Shreveport
# saint-pierre - nearest hotel: Tropic Hotel
#                    City Country      Lat       Lng  Humidity  \
# 78            iowa park      US  33.9515  -98.6687        55
# 82          dhromolaxia      CY  34.8755   33.5868        82
# 152      citrus springs      US  28.9975  -82.4707        77
# 193          fort bragg      US  35.1390  -79.0060        91
# 204              tiznit      MA  29.5833   -9.5000        56
# 247                dori      BF  14.0354   -0.0345        17
# 346  madinat ash shamal      QA  26.1293   51.2009        70
# 350             omaruru     NaN -21.4333   15.9333        29
# 376              laurel      US  39.0993  -76.8483        64
# 389           kerrville      US  30.0474  -99.1403        60
# 404             salalah      OM  17.0151   54.0924        60
# 420            mankapur      IN  27.0333   82.2333        65
# 429               dunda      TZ  -8.1167   34.2500        68
# 443            cam ranh      VN  11.9214  109.1591        94
# 446          jaguariuna      BR -22.7056  -46.9858        54
# 470                tura      IN  25.5198   90.2201        88
# 471        port augusta      AU -32.5000  137.7667        52
# 502          shreveport      US  32.5251  -93.7502        56
# 551        saint-pierre      RE -21.3393   55.4781        78
#
#                                  Hotel Name
# 78                           No hotel found
# 82                    Helen of Troy gardens
# 152                          Comfort Suites
# 193                    Airborne Inn Lodging
# 204                          No hotel found
# 247                          Kuin Deni Dori
# 346                          No hotel found
# 350                           Central Hotel
# 376                    Quality Inn & Suites
# 389                        Inn Of The Hills
# 404              Muscat International Hotel
# 420                          No hotel found
# 429                          No hotel found
# 443                     Khách sạn Thái Bình
# 446                           Hotel Jaguary
# 470                       Hotel Polo Orchid
# 471                      Hotel Commonwealth
# 502  Sam's Town Hotel and Casino Shreveport
# 551                            Tropic Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display


#NOTE: IF YOU CAN'T SE THE MAP TILE, PLEASE ALTERNATE BETWEEN TRUE OR FALSE VALUES FOR "GEO" PARAMETER

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    size = "Humidity",
    geo = False,
    tiles = "OSM",
    color = "City",
    hover_cols=["Hotel Name","Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [x,y]   (City,Humidity,Hotel Name,Country)
